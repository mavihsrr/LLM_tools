# %%
# !git clone https://github.com/cg123/mergekit.git
# %cd mergekit

# !pip install -e .  # install the package and make scripts available
# Out:
# Cloning into 'mergekit'...
# remote: Enumerating objects: 1051, done.
# remote: Counting objects: 100% (511/511), done.
# remote: Compressing objects: 100% (209/209), done.
# remote: Total 1051 (delta 387), reused 386 (delta 300), pack-reused 540
# Receiving objects: 100% (1051/1051), 273.70 KiB | 1.44 MiB/s, done.
# Resolving deltas: 100% (717/717), done.
# /content/mergekit
# Obtaining file:///content/mergekit
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Installing backend dependencies ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from mergekit==0.0.3.2) (2.1.0+cu121)
# Requirement already satisfied: tqdm==4.66.1 in /usr/local/lib/python3.10/dist-packages (from mergekit==0.0.3.2) (4.66.1)
# Requirement already satisfied: click==8.1.7 in /usr/local/lib/python3.10/dist-packages (from mergekit==0.0.3.2) (8.1.7)
# Requirement already satisfied: safetensors==0.4.1 in /usr/local/lib/python3.10/dist-packages (from mergekit==0.0.3.2) (0.4.1)
# Collecting accelerate==0.25.0 (from mergekit==0.0.3.2)
#   Downloading accelerate-0.25.0-py3-none-any.whl (265 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.7/265.7 kB 4.8 MB/s eta 0:00:00
# Collecting pydantic==2.5.3 (from mergekit==0.0.3.2)
#   Downloading pydantic-2.5.3-py3-none-any.whl (381 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 381.9/381.9 kB 8.5 MB/s eta 0:00:00
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (from mergekit==0.0.3.2) (4.35.2)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from mergekit==0.0.3.2) (0.20.2)
# Collecting peft (from mergekit==0.0.3.2)
#   Downloading peft-0.7.1-py3-none-any.whl (168 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.3/168.3 kB 10.1 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from mergekit==0.0.3.2) (4.5.0)
# Collecting sentencepiece (from mergekit==0.0.3.2)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 15.0 MB/s eta 0:00:00
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from mergekit==0.0.3.2) (3.20.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate==0.25.0->mergekit==0.0.3.2) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate==0.25.0->mergekit==0.0.3.2) (23.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate==0.25.0->mergekit==0.0.3.2) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate==0.25.0->mergekit==0.0.3.2) (6.0.1)
# Collecting annotated-types>=0.4.0 (from pydantic==2.5.3->mergekit==0.0.3.2)
#   Downloading annotated_types-0.6.0-py3-none-any.whl (12 kB)
# Collecting pydantic-core==2.14.6 (from pydantic==2.5.3->mergekit==0.0.3.2)
#   Downloading pydantic_core-2.14.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 21.6 MB/s eta 0:00:00
# Collecting typing-extensions (from mergekit==0.0.3.2)
#   Downloading typing_extensions-4.9.0-py3-none-any.whl (32 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->mergekit==0.0.3.2) (3.13.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->mergekit==0.0.3.2) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->mergekit==0.0.3.2) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->mergekit==0.0.3.2) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->mergekit==0.0.3.2) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->mergekit==0.0.3.2) (2.1.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->mergekit==0.0.3.2) (2.31.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers->mergekit==0.0.3.2) (2023.6.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers->mergekit==0.0.3.2) (0.15.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=2.0.0->mergekit==0.0.3.2) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->mergekit==0.0.3.2) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->mergekit==0.0.3.2) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->mergekit==0.0.3.2) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->mergekit==0.0.3.2) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=2.0.0->mergekit==0.0.3.2) (1.3.0)
# Building wheels for collected packages: mergekit
#   Building editable for mergekit (pyproject.toml) ... done
#   Created wheel for mergekit: filename=mergekit-0.0.3.2-0.editable-py3-none-any.whl size=9027 sha256=f432709d089e7c53152a71800dd5a8c2afed6b3f2ec61db3c14b8d1cfeab35e4
#   Stored in directory: /tmp/pip-ephem-wheel-cache-hs734hwx/wheels/ed/19/4a/2c5e8cd746584b45b047bcbc1cbf1cc31ccf037775edec8120
# Successfully built mergekit
# Installing collected packages: sentencepiece, typing-extensions, annotated-types, pydantic-core, pydantic, accelerate, peft, mergekit
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.5.0
#     Uninstalling typing_extensions-4.5.0:
#       Successfully uninstalled typing_extensions-4.5.0
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.10.13
#     Uninstalling pydantic-1.10.13:
#       Successfully uninstalled pydantic-1.10.13
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires openai, which is not installed.
# llmx 0.0.15a0 requires tiktoken, which is not installed.
# tensorflow-probability 0.22.0 requires typing-extensions<4.6.0, but you have typing-extensions 4.9.0 which is incompatible.
# Successfully installed accelerate-0.25.0 annotated-types-0.6.0 mergekit-0.0.3.2 peft-0.7.1 pydantic-2.5.3 pydantic-core-2.14.6 sentencepiece-0.1.99 typing-extensions-4.9.0

# %%
OUTPUT_PATH = "./merged"  # folder to store the result in
LORA_MERGE_CACHE = "/tmp"  # change if you want to keep these for some reason
CONFIG_YML = "/content/mergeconfig.yaml"  # merge configuration file
COPY_TOKENIZER = True  # you want a tokenizer? yeah, that's what i thought
LAZY_UNPICKLE = False  # experimental low-memory model loader
LOW_CPU_MEMORY = False  # enable if you somehow have more VRAM than RAM+swap

# %%
# actually do merge
import torch
import yaml

from mergekit.config import MergeConfiguration
from mergekit.merge import MergeOptions, run_merge

with open(CONFIG_YML, "r", encoding="utf-8") as fp:
    merge_config = MergeConfiguration.model_validate(yaml.safe_load(fp))

run_merge(
    merge_config,
    out_path=OUTPUT_PATH,
    options=MergeOptions(
        lora_merge_cache=LORA_MERGE_CACHE,
        cuda=torch.cuda.is_available(),
        copy_tokenizer=COPY_TOKENIZER,
        lazy_unpickle=LAZY_UNPICKLE,
        low_cpu_memory=LOW_CPU_MEMORY,
    ),
)
print("Done!")
# Out:
# Fetching 11 files:   0%|          | 0/11 [00:00<?, ?it/s]
# Fetching 8 files:   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/93 [00:00<?, ?it/s]WARNING:root:Using common submatrix of size torch.Size([32000, 2048]) for model.embed_tokens.weight
#   0%|          | 0/93 [00:03<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-ab05f39bfac7> in <cell line: 11>()
#       9     merge_config = MergeConfiguration.model_validate(yaml.safe_load(fp))
#      10
# ---> 11 run_merge(
#      12     merge_config,
#      13     out_path=OUTPUT_PATH,
#
# /content/mergekit/mergekit/merge.py in run_merge(merge_config, out_path, options, config_source)
#     109         lazy_unpickle=options.lazy_unpickle,
#     110     )
# --> 111     exec.run(
#     112         out_path,
#     113         max_shard_size=options.out_shard_size,
#
# /content/mergekit/mergekit/graph.py in run(self, out_path, max_shard_size, clone_tensors, safe_serialization)
#     259             safe_serialization=safe_serialization,
#     260         )
# --> 261         for ref, tensor in tqdm.tqdm(self.generate_tensors(), total=len(self.targets)):
#     262             if not self.low_cpu_memory:
#     263                 tensor = tensor.cpu()
#
# /usr/local/lib/python3.10/dist-packages/tqdm/std.py in __iter__(self)
#    1180
#    1181         try:
# -> 1182             for obj in iterable:
#    1183                 yield obj
#    1184                 # Update and possibly print the progressbar.
#
# /content/mergekit/mergekit/graph.py in generate_tensors(self)
#     297                 tensor_args[ref] = value
#     298
# --> 299             res = self._perform_operation(operation, tensor_args)
#     300             del tensor_args
#     301
#
# /content/mergekit/mergekit/graph.py in _perform_operation(self, operation, tensor_args)
#     329
#     330         if operation.function in self.operations:
# --> 331             return self.operations[operation.function](
#     332                 input_tensors=tensor_args, **operation.kwargs
#     333             )
#
# /content/mergekit/mergekit/merge_methods/slerp.py in __call__(self, parameter_name, input_tensors, config, **kwargs)
#      46
#      47         return (
# ---> 48             slerp(
#      49                 config.parameter("t", required=True),
#      50                 prepped_tensors[0],
#
# /content/mergekit/mergekit/merge_methods/slerp.py in slerp(t, v0, v1, DOT_THRESHOLD, eps)
#      88     if not isinstance(v1, np.ndarray):
#      89         is_torch = True
# ---> 90         v1 = v1.detach().cpu().float().numpy()
#      91
#      92     # Copy the vectors to reuse them later
#
# KeyboardInterrupt:

# %%
# !pip install --upgrade typing-extensions
# Out:
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (4.9.0)
